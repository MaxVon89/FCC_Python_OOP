# %%
# class Company:
#     def __init__(self, name):
#         self.name=name

# class Employee:
#     def __init__(self, name, email, ID, Company):
#         self.name=name
#         self.email=email
#         self.ID=ID
#         self.Company = Company
        
    
#     def constructEmail(self):
#         self.email = self.name.lower() +'@' + self.Company.name.lower() + '.com'
#         print(self.email)

# %%
# NVIDIA = Company('NVIDIA')

# e1 = Employee('Max', 0, 1, NVIDIA)
# print(e1.constructEmail())
# Out:
# manas@nvidia.com
# None

# %%
# But here, anyone can access and modify the data

# e1.email=0
# e1.ID=0

# %% [markdown]
# #### Approach I:
#     getter()
#     setter()
#
# and modifying the datapoints to Protected

# %%
# #conv. to Private by adding '_' when assigning to 'self'

# class Company:
#     def __init__(self, name):
#         self._name=name

# class Employee:
#     def __init__(self, name, email, ID, Company):
#         self._name=name
#         self._email=email
#         self._ID=ID
#         self._Company = Company
        
    
#     def constructEmail(self):
#         self.email = self.name.lower() +'@' + self.Company.name.lower() + '.com'
#         print(self.email)


#     def getName(self):
#         return self._name
    
#     def getEmail(self):
#         return self._email
    
#     def getID(self):
#         return self._ID

# %%
# NVIDIA = Company('NVIDIA')

# e1 = Employee('Max', 0, 1, NVIDIA)

# print(e1._name)
# Out:
# Max

# %%
# print(e1.getName())
# print(e1.getEmail())
# print(e1.getID())
# Out:
# Max
# 0
# 1

# %% [markdown]
# Here the datapoints _can_ still be accessed, but if it's absolutely imp. to disallow wanton access to data, a `dunder` can be added when assigning to 'self'

# %%
class Company:
    def __init__(self, name):
        self.name=name

class Employee:
    def __init__(self, name, email, ID, Company):
        self.__name=name
        self.__email=email
        self.__eID=ID
        self.__Company = Company
        
    
    def constructEmail(self):
        self.email = self.name.lower() +'@' + self.Company.name.lower() + '.com'
        print(self.email)


    def getName(self):
        return self.__name
    
    def getEmail(self):
        return self.__email
    
    def getID(self):
        return self.__eID
    
    def getCompany(self):
        return self.__Company.name

# %%
NVIDIA = Company('NVIDIA')

e1 = Employee('Manas', 0, 1, NVIDIA)

# Now this throws error:
# print(e1.constructEmail())

# %%
# Still no:
e1.getEmail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 e1.getEmail()
#
# AttributeError: 'Employee' object has no attribute 'getEmail'

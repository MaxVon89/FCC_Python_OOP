# %%
# Why 'self' in a param in a class methods

class something:
    def __init__(self, x, y, z):
        pass

    def doSome(self):
        pass


# Now
a1 = something

# What's happening in the backrgound
# something(a1, x, y, z)

# It's referencing a specific instance of a class
